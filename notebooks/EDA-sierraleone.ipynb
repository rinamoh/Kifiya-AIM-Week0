# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Ismael Akmel\Desktop\Kifiya-Ai\Kifiya-AIM-Week0\notebooks

# %%
data=pd.read_csv("sierraleone-bumbuna.csv")

data.head()
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
data.shape
# Out:
# (525600, 19)

# %%
data.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  object
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
# ...

# %%
#to check for missing values in the columns
data.isnull().sum() #will give us the number of null values summed up in each column - from the results it seems like comments is full of null values.
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
#to remove outliers

def removal_box_plot(df, column):

    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define outlier boundaries
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    removed_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

# %%
no_outliers = removal_box_plot(data, 'GHI')

# %%
no_outliers = removal_box_plot(data, 'DHI')

# %%
no_outliers = removal_box_plot(data, 'ModA')

# %%
no_outliers = removal_box_plot(data, 'DNI')

# %%
no_outliers = removal_box_plot(data, 'ModB')

# %%
no_outliers = removal_box_plot(data, 'Tamb')

# %%
no_outliers = removal_box_plot(data, 'RH')

# %%
no_outliers = removal_box_plot(data, 'WS')

# %%
no_outliers = removal_box_plot(data, 'WSgust')

# %%
no_outliers = removal_box_plot(data, 'WSstdev')

# %%
no_outliers = removal_box_plot(data, 'WD')

# %%
no_outliers = removal_box_plot(data, 'WDstdev')

# %%
no_outliers = removal_box_plot(data, 'WDstdev')

# %%
no_outliers = removal_box_plot(data, 'BP')

# %%
no_outliers = removal_box_plot(data, 'Precipitation')

# %%
no_outliers = removal_box_plot(data, 'TModA')

# %%
no_outliers = removal_box_plot(data, 'TModB')

# %%
# Identify outliers
outliers = (z_scores.abs() > threshold)

no_outliers = data[~outliers.any(axis=1)]
print(z_scores.head())
# Out:
#    Precipitation       DNI
# 0      -0.101059 -0.532701
# 1      -0.101059 -0.532701
# 2      -0.101059 -0.532701
# 3       2.001728 -0.532243
# 4      -0.101059 -0.532701

# %%
#calculate z score 
from scipy.stats import zscore
def removal_box_zscore(df,column):

    z_scores= data[['Precipitation','DNI']].apply(zscore)
    threshold = 3

    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    removed_outliers = df[(df[column] >= threshold)]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

# %%
#THIS CODE IS NOT WORKING
no_outliers = removal_box_zscore(data, 'Precipitation')

# %%
no_outliers = removal_box_zscore(data, 'DNI')
